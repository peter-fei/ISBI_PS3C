# %% [markdown]
# <a href="https://www.kaggle.com/code/jht010312/ps3c-solution?scriptVersionId=222481661" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# This is the 1st place solution for ISBI_PS3C.
#
# All the code has been released on GitHub at https://github.com/peter-fei/ISBI_PS3C.git.
